# %%
import pandas as pd
import numpy as np

# %%
#1
mrg_match_biomarkers= pd.read_csv('/Users/Sara/Desktop/git_101/jupyter/mrg_match_biomarkers.csv')
mrg_match_biomarkers.info()
# Out:
# C:\Users\Sara\AppData\Local\Temp\ipykernel_28532\2464213773.py:2: DtypeWarning: Columns (5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   mrg_match_biomarkers= pd.read_csv('/Users/Sara/Desktop/git_101/jupyter/mrg_match_biomarkers.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47972 entries, 0 to 47971
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       47972 non-null  int64
#  1   compound_id                      47972 non-null  int64
#  2   foodb_id                         47972 non-null  object
#  3   Foodb_name                       47972 non-null  object
#  4   InChI                            47972 non-null  object
#  5   ChEBI                            1426 non-null   object
#  6   KEGG                             500 non-null    object
# ...

# %%
mrg_match_biomarkers["ChEBI_id"] = mrg_match_biomarkers[["ChEBI", "chebi_id","ChEBI ID"]].apply(lambda x: ', '.join(map(str,(x[x.notnull()]))), axis = 1)

# %%
mrg_match_biomarkers["KEGG_id"] = mrg_match_biomarkers[["KEGG", "kegg_id"]].apply(lambda x: ', '.join(map(str,(x[x.notnull()]))), axis = 1)

# %%
mrg_match_biomarkers.info()
mrg_match_biomarkers.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47972 entries, 0 to 47971
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       47972 non-null  int64
#  1   compound_id                      47972 non-null  int64
#  2   foodb_id                         47972 non-null  object
#  3   Foodb_name                       47972 non-null  object
#  4   InChI                            47972 non-null  object
#  5   ChEBI                            1426 non-null   object
#  6   KEGG                             500 non-null    object
#  7   Lipidmaps                        752 non-null    object
#  8   BioCyc                           207 non-null    object
#  9   Unkown_db                        175 non-null    object
#  10  HMDB_name                        47972 non-null  object
#  11  InChIKey                         47972 non-null  object
# ...

# %%
mrg_match_biomarkers.loc[163,:]
# Out:
# Unnamed: 0                                                                       165
# compound_id                                                                      447
# foodb_id                                                                   FDB000447
# Foodb_name                                                                Papaverine
# InChI                              InChI=1S/C20H21NO4/c1-22-17-6-5-13(10-18(17)23...
# ChEBI                                                                    CHEBI:28241
# KEGG                                                                          C06533
# Lipidmaps                                                                        NaN
# BioCyc                                                                           NaN
# Unkown_db                                                                        NaN
# HMDB_name                                                                 Papaverine
# ...

# %%
new= mrg_match_biomarkers.drop(['Unnamed: 0',"ChEBI", "chebi_id","ChEBI ID","KEGG", "kegg_id"], axis=1)

# %%
new= new[['foodb_id','Foodb_name','biomarkers_name','HMDB_name','InChI','InChIKey','HMDB_ID','ChEBI_id','KEGG_id','Lipidmaps','BioCyc','Unkown_db','No. of Publications','No. of Correlation values','No. of Metabolomic associations','No. of Cancer associations']]

# %%
new.info()
new.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47972 entries, 0 to 47971
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   foodb_id                         47972 non-null  object
#  1   Foodb_name                       47972 non-null  object
#  2   biomarkers_name                  449 non-null    object
#  3   HMDB_name                        47972 non-null  object
#  4   InChI                            47972 non-null  object
#  5   InChIKey                         47972 non-null  object
#  6   HMDB_ID                          441 non-null    object
#  7   ChEBI_id                         47972 non-null  object
#  8   KEGG_id                          47972 non-null  object
#  9   Lipidmaps                        752 non-null    object
#  10  BioCyc                           207 non-null    object
#  11  Unkown_db                        175 non-null    object
# ...

# %%
new = new.replace(r'^\s*$', np.nan, regex=True)

# %%
new.info()
new.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47972 entries, 0 to 47971
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   foodb_id                         47972 non-null  object
#  1   Foodb_name                       47972 non-null  object
#  2   biomarkers_name                  449 non-null    object
#  3   HMDB_name                        47972 non-null  object
#  4   InChI                            47972 non-null  object
#  5   InChIKey                         47972 non-null  object
#  6   HMDB_ID                          441 non-null    object
#  7   ChEBI_id                         7887 non-null   object
#  8   KEGG_id                          4198 non-null   object
#  9   Lipidmaps                        752 non-null    object
#  10  BioCyc                           207 non-null    object
#  11  Unkown_db                        175 non-null    object
# ...

# %%
new.to_csv('mrg_match_biomarkers.csv')
